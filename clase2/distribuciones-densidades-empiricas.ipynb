# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_ventas = pd.read_excel('./datos_ventas.xlsx')
df_ventas
# Out:
#          Fecha        Ventas
# 0   2023-01-01  12900.965726
# 1   2023-01-02  14962.847415
# 2   2023-01-03  17328.133221
# 3   2023-01-04  19080.675831
# 4   2023-01-05  16665.614172
# ..         ...           ...
# 360 2023-12-27  19031.854755
# 361 2023-12-28  19089.011703
# 362 2023-12-29  18652.849423
# 363 2023-12-30  22331.115699
# 364 2023-12-31  14789.525978
#
# [365 rows x 2 columns]

# %%
ventas = df_ventas['Ventas']
len(ventas)
# Out:
# 365

# %%
# Función de distribución de la variable ventas
sns.ecdfplot(ventas)
# Out:
# <Axes: xlabel='Ventas', ylabel='Proportion'>

# %%
# Histograma de la variable ventas
sns.histplot(ventas, stat='density')
# Out:
# <Axes: xlabel='Ventas', ylabel='Density'>

# %%
# Aproximacion a la densidad de probabilidad
sns.kdeplot(ventas)
# Out:
# <Axes: xlabel='Ventas', ylabel='Density'>
